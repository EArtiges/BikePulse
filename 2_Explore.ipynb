# %% [markdown]
# # Obtain City data

# %%
import requests
import pandas as pd
import matplotlib.pyplot as plt
from scipy.spatial import distance_matrix
from shapely.ops import Point
import geopandas as gpd
import contextily as ctx
import numpy as np
import oslo_lib

import importlib as imp
imp.reload(oslo_lib)
# Out:
# <module 'oslo_lib' from '/Users/emmanuel/Documents/code/BikePulse/oslo_lib.py'>

# %%
city = 'Milan'
city_crs = {"Oslo": 'epsg:27393', "Milan":"epsg:3003"}[city]

stations = pd.read_pickle(f'{city}/stations.pkl')
stations = oslo_lib.get_geostations(stations, city_crs)

stations_GPS = stations.geometry.apply(lambda x : [x.x, x.y]).to_list()
station_distances = pd.DataFrame(index=stations.index, 
                                 columns=stations.index, 
                                 data=distance_matrix(stations_GPS, stations_GPS)
                                ).astype(int)

station_distances.to_pickle(f'{city}/station_distances.pkl')

try:
    trips = pd.read_pickle(f'{city}/processed_trips.pkl')
except FileNotFoundError:
    trips = oslo_lib.get_processed_trips(pd.read_pickle(f'{city}/trips.pkl'), 
                                         station_distances)
    trips.to_pickle(f'{city}/processed_trips.pkl')

# %% [markdown]
# ### Trips nature

# %%
n_trips = len(trips)
print(n_trips, 'total trips')
n_roundtrips = len(trips[trips.distance==0])
print(n_roundtrips, f'round trips ({np.round(100 * n_roundtrips/n_trips, 1)} %)')
# Out:
# 5749964 total trips
# 202917 round trips (3.5 %)

# %%
fig, axes = plt.subplots(1,3, figsize=(18,4))
trips.distance.hist(bins=20, ax=axes[0])
axes[0].set_title('distance in m')

trips.duration_min.apply(lambda x : min(x, 60)).hist(bins=20, ax=axes[1])
axes[1].set_title('duration in min')

trips.speed_kmh.hist(bins=20, ax=axes[2])
axes[2].set_title('average speed in km/h')
plt.show()

# %%
bin=500
trips['distance_bin'] = trips.distance//bin
for groupby_dim in 'quarter', 'weekday':
    t = trips.groupby(groupby_dim).distance_bin.value_counts().unstack(level=0)
    t = t / t.sum()
    t.plot.bar(figsize=(16,4))
    plt.show()

# %%
n_points = 1000

fig, axes = plt.subplots(2,2,figsize=(16,8))
axes=axes.flatten()


t = trips.query('duration_min<61 and distance>0')
sample = t.sample(n_points)
sample.plot.scatter(x='distance', 
                    y='duration_min', 
                    c=sample.speed_kmh>10,
                    cmap='plasma',
                    alpha=.1,
                    ax=axes[0], 
                    title=' sampled distance / duration scatter plot',
                    )

t.groupby('weekday').speed_kmh.mean().plot(yerr=trips.groupby('weekday').speed_kmh.std(), 
                                               ax=axes[1], 
                                               title='average speed per weekday')
t.groupby(['hour', 'weekend']).speed_kmh.mean().unstack().plot(ax=axes[2], title='Average speed per hour during the week/weekends. \nSize is number of trips.')
axes[2].grid()

for wk, c in zip([False, True], ['blue', 'orange']):
    t = pd.concat([trips.query('duration_min<61 and distance>0').query(f'weekend == {wk}').groupby('hour').trip.sum(), 
                   trips.query('duration_min<61 and distance>0').query(f'weekend == {wk}').groupby('hour').speed_kmh.mean()], axis=1).reset_index()
    t.plot.scatter(x='hour', 
                   y='speed_kmh', 
                   s = t.trip//1000, alpha=.3, 
                   ax=axes[2],
                  c=c)

t = pd.concat([trips.groupby('hour').trip.sum(), 
               trips.groupby('hour').speed_kmh.mean()], axis=1).reset_index()
t.plot.scatter(x='hour', 
               y='speed_kmh', 
               s = t.trip//1000, alpha=.3, 
               ax=axes[3],
              title='number of trips per hour, weekend and weekdays together')
plt.tight_layout()

# %% [markdown]
# ### Temporality

# %%
calendar = trips.groupby(['year', 'week']).trip.sum().unstack().fillna(0).astype(int).T
calendar.plot(figsize=(18,4))
# Out:
# <Axes: xlabel='week'>

# %%
calendar = trips.groupby(['hour', 'weekday']).trip.sum().unstack().fillna(0).astype(int)

day_names = ['M', 'T', 'W', 'Th', 'F', 'St', 'Sn']
calendar.columns = day_names
calendar.style.background_gradient(cmap='Blues')
# Out:
# <style type="text/css">
# #T_b7d6b_row0_col0, #T_b7d6b_row0_col1, #T_b7d6b_row0_col2 {
#   background-color: #f6faff;
#   color: #000000;
# }
# #T_b7d6b_row0_col3 {
#   background-color: #f5fafe;
#   color: #000000;
# }
# #T_b7d6b_row0_col4 {
#   background-color: #f5f9fe;
#   color: #000000;
# }
# #T_b7d6b_row0_col5 {
#   background-color: #eaf3fb;
#   color: #000000;
# }
# #T_b7d6b_row0_col6 {
#   background-color: #e9f2fa;
#   color: #000000;
# }
# #T_b7d6b_row1_col0, #T_b7d6b_row1_col1, #T_b7d6b_row1_col2, #T_b7d6b_row1_col3, #T_b7d6b_row1_col4, #T_b7d6b_row1_col5, #T_b7d6b_row1_col6 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_b7d6b_row2_col0, #T_b7d6b_row2_col1, #T_b7d6b_row2_col2, #T_b7d6b_row2_col4, #T_b7d6b_row2_col5 {
#   background-color: #eef5fc;
#   color: #000000;
# }
# #T_b7d6b_row2_col3, #T_b7d6b_row21_col3 {
#   background-color: #eff6fc;
#   color: #000000;
# }
# #T_b7d6b_row2_col6 {
#   background-color: #f0f6fd;
#   color: #000000;
# }
# #T_b7d6b_row3_col0, #T_b7d6b_row3_col1 {
#   background-color: #b8d5ea;
#   color: #000000;
# }
# #T_b7d6b_row3_col2 {
#   background-color: #b9d6ea;
#   color: #000000;
# }
# #T_b7d6b_row3_col3 {
#   background-color: #bcd7eb;
#   color: #000000;
# }
# #T_b7d6b_row3_col4 {
#   background-color: #b5d4e9;
#   color: #000000;
# }
# #T_b7d6b_row3_col5 {
#   background-color: #d9e7f5;
#   color: #000000;
# }
# #T_b7d6b_row3_col6 {
#   background-color: #e5eff9;
#   color: #000000;
# }
# #T_b7d6b_row4_col0, #T_b7d6b_row15_col3 {
#   background-color: #084387;
#   color: #f1f1f1;
# }
# #T_b7d6b_row4_col1, #T_b7d6b_row4_col2 {
#   background-color: #083d7f;
#   color: #f1f1f1;
# }
# #T_b7d6b_row4_col3, #T_b7d6b_row8_col5 {
#   background-color: #084c95;
#   color: #f1f1f1;
# }
# #T_b7d6b_row4_col4, #T_b7d6b_row12_col6, #T_b7d6b_row15_col1 {
#   background-color: #08458a;
#   color: #f1f1f1;
# }
# #T_b7d6b_row4_col5, #T_b7d6b_row7_col3 {
#   background-color: #b0d2e7;
#   color: #000000;
# }
# #T_b7d6b_row4_col6, #T_b7d6b_row19_col2 {
#   background-color: #d2e3f3;
#   color: #000000;
# }
# #T_b7d6b_row5_col0 {
#   background-color: #083776;
#   color: #f1f1f1;
# }
# #T_b7d6b_row5_col1, #T_b7d6b_row5_col2, #T_b7d6b_row5_col3, #T_b7d6b_row5_col4, #T_b7d6b_row14_col0, #T_b7d6b_row14_col5, #T_b7d6b_row14_col6 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_b7d6b_row5_col5, #T_b7d6b_row6_col2 {
#   background-color: #64a9d3;
#   color: #f1f1f1;
# }
# #T_b7d6b_row5_col6 {
#   background-color: #9dcae1;
#   color: #000000;
# }
# #T_b7d6b_row6_col0, #T_b7d6b_row6_col1 {
#   background-color: #65aad4;
#   color: #f1f1f1;
# }
# #T_b7d6b_row6_col3, #T_b7d6b_row17_col5 {
#   background-color: #5da5d1;
#   color: #f1f1f1;
# }
# #T_b7d6b_row6_col4, #T_b7d6b_row9_col4 {
#   background-color: #4b98ca;
#   color: #f1f1f1;
# }
# #T_b7d6b_row6_col5 {
#   background-color: #2c7cba;
#   color: #f1f1f1;
# }
# #T_b7d6b_row6_col6 {
#   background-color: #4997c9;
#   color: #f1f1f1;
# }
# #T_b7d6b_row7_col0, #T_b7d6b_row7_col2 {
#   background-color: #b3d3e8;
#   color: #000000;
# }
# #T_b7d6b_row7_col1 {
#   background-color: #b7d4ea;
#   color: #000000;
# }
# #T_b7d6b_row7_col4 {
#   background-color: #97c6df;
#   color: #000000;
# }
# #T_b7d6b_row7_col5 {
#   background-color: #115ca5;
#   color: #f1f1f1;
# }
# #T_b7d6b_row7_col6 {
#   background-color: #1f6eb3;
#   color: #f1f1f1;
# }
# #T_b7d6b_row8_col0 {
#   background-color: #a5cde3;
#   color: #000000;
# }
# #T_b7d6b_row8_col1, #T_b7d6b_row17_col2 {
#   background-color: #a8cee4;
#   color: #000000;
# }
# #T_b7d6b_row8_col2, #T_b7d6b_row8_col3 {
#   background-color: #a3cce3;
#   color: #000000;
# }
# #T_b7d6b_row8_col4, #T_b7d6b_row9_col3 {
#   background-color: #7ab6d9;
#   color: #000000;
# }
# #T_b7d6b_row8_col6 {
#   background-color: #105ba4;
#   color: #f1f1f1;
# }
# #T_b7d6b_row9_col0 {
#   background-color: #7cb7da;
#   color: #000000;
# }
# #T_b7d6b_row9_col1, #T_b7d6b_row12_col0 {
#   background-color: #7fb9da;
#   color: #000000;
# }
# #T_b7d6b_row9_col2 {
#   background-color: #79b5d9;
#   color: #000000;
# }
# #T_b7d6b_row9_col5 {
#   background-color: #09529d;
#   color: #f1f1f1;
# }
# #T_b7d6b_row9_col6, #T_b7d6b_row10_col5 {
#   background-color: #1764ab;
#   color: #f1f1f1;
# }
# #T_b7d6b_row10_col0 {
#   background-color: #6dafd7;
#   color: #f1f1f1;
# }
# #T_b7d6b_row10_col1 {
#   background-color: #72b2d8;
#   color: #f1f1f1;
# }
# #T_b7d6b_row10_col2, #T_b7d6b_row17_col6 {
#   background-color: #6fb0d7;
#   color: #f1f1f1;
# }
# #T_b7d6b_row10_col3 {
#   background-color: #6aaed6;
#   color: #f1f1f1;
# }
# #T_b7d6b_row10_col4, #T_b7d6b_row13_col2, #T_b7d6b_row13_col3 {
#   background-color: #4493c7;
#   color: #f1f1f1;
# }
# #T_b7d6b_row10_col6 {
#   background-color: #2676b8;
#   color: #f1f1f1;
# }
# #T_b7d6b_row11_col0, #T_b7d6b_row11_col3 {
#   background-color: #82bbdb;
#   color: #000000;
# }
# #T_b7d6b_row11_col1 {
#   background-color: #8abfdd;
#   color: #000000;
# }
# #T_b7d6b_row11_col2, #T_b7d6b_row12_col3 {
#   background-color: #85bcdc;
#   color: #000000;
# }
# #T_b7d6b_row11_col4 {
#   background-color: #549fcd;
#   color: #f1f1f1;
# }
# #T_b7d6b_row11_col5 {
#   background-color: #0e58a2;
#   color: #f1f1f1;
# }
# #T_b7d6b_row11_col6 {
#   background-color: #1865ac;
#   color: #f1f1f1;
# }
# #T_b7d6b_row12_col1 {
#   background-color: #89bedc;
#   color: #000000;
# }
# #T_b7d6b_row12_col2, #T_b7d6b_row19_col5 {
#   background-color: #87bddc;
#   color: #000000;
# }
# #T_b7d6b_row12_col4 {
#   background-color: #529dcc;
#   color: #f1f1f1;
# }
# #T_b7d6b_row12_col5 {
#   background-color: #084184;
#   color: #f1f1f1;
# }
# #T_b7d6b_row13_col0 {
#   background-color: #3888c1;
#   color: #f1f1f1;
# }
# #T_b7d6b_row13_col1 {
#   background-color: #4191c6;
#   color: #f1f1f1;
# }
# #T_b7d6b_row13_col4 {
#   background-color: #2171b5;
#   color: #f1f1f1;
# }
# #T_b7d6b_row13_col5 {
#   background-color: #083370;
#   color: #f1f1f1;
# }
# #T_b7d6b_row13_col6 {
#   background-color: #083471;
#   color: #f1f1f1;
# }
# #T_b7d6b_row14_col1 {
#   background-color: #083b7c;
#   color: #f1f1f1;
# }
# #T_b7d6b_row14_col2, #T_b7d6b_row14_col3 {
#   background-color: #084488;
#   color: #f1f1f1;
# }
# #T_b7d6b_row14_col4 {
#   background-color: #083c7d;
#   color: #f1f1f1;
# }
# #T_b7d6b_row15_col0 {
#   background-color: #083674;
#   color: #f1f1f1;
# }
# #T_b7d6b_row15_col2 {
#   background-color: #08478d;
#   color: #f1f1f1;
# }
# #T_b7d6b_row15_col4 {
#   background-color: #084b93;
#   color: #f1f1f1;
# }
# #T_b7d6b_row15_col5 {
#   background-color: #083a7a;
#   color: #f1f1f1;
# }
# #T_b7d6b_row15_col6 {
#   background-color: #084082;
#   color: #f1f1f1;
# }
# #T_b7d6b_row16_col0 {
#   background-color: #3b8bc2;
#   color: #f1f1f1;
# }
# #T_b7d6b_row16_col1 {
#   background-color: #4695c8;
#   color: #f1f1f1;
# }
# #T_b7d6b_row16_col2 {
#   background-color: #4594c7;
#   color: #f1f1f1;
# }
# #T_b7d6b_row16_col3 {
#   background-color: #4292c6;
#   color: #f1f1f1;
# }
# #T_b7d6b_row16_col4 {
#   background-color: #3f8fc5;
#   color: #f1f1f1;
# }
# #T_b7d6b_row16_col5 {
#   background-color: #1a68ae;
#   color: #f1f1f1;
# }
# #T_b7d6b_row16_col6 {
#   background-color: #2474b7;
#   color: #f1f1f1;
# }
# #T_b7d6b_row17_col0, #T_b7d6b_row17_col3 {
#   background-color: #a4cce3;
#   color: #000000;
# }
# #T_b7d6b_row17_col1 {
#   background-color: #add0e6;
#   color: #000000;
# }
# #T_b7d6b_row17_col4 {
#   background-color: #94c4df;
#   color: #000000;
# }
# #T_b7d6b_row18_col0 {
#   background-color: #cfe1f2;
#   color: #000000;
# }
# #T_b7d6b_row18_col1 {
#   background-color: #d0e1f2;
#   color: #000000;
# }
# #T_b7d6b_row18_col2 {
#   background-color: #cde0f1;
#   color: #000000;
# }
# #T_b7d6b_row18_col3 {
#   background-color: #cbdef1;
#   color: #000000;
# }
# #T_b7d6b_row18_col4 {
#   background-color: #bdd7ec;
#   color: #000000;
# }
# #T_b7d6b_row18_col5 {
#   background-color: #8cc0dd;
#   color: #000000;
# }
# #T_b7d6b_row18_col6 {
#   background-color: #9fcae1;
#   color: #000000;
# }
# #T_b7d6b_row19_col0, #T_b7d6b_row20_col6 {
#   background-color: #d7e6f5;
#   color: #000000;
# }
# #T_b7d6b_row19_col1 {
#   background-color: #d6e5f4;
#   color: #000000;
# }
# #T_b7d6b_row19_col3 {
#   background-color: #d1e2f3;
#   color: #000000;
# }
# #T_b7d6b_row19_col4 {
#   background-color: #c7dbef;
#   color: #000000;
# }
# #T_b7d6b_row19_col6 {
#   background-color: #aed1e7;
#   color: #000000;
# }
# #T_b7d6b_row20_col0 {
#   background-color: #e8f1fa;
#   color: #000000;
# }
# #T_b7d6b_row20_col1 {
#   background-color: #e6f0f9;
#   color: #000000;
# }
# #T_b7d6b_row20_col2 {
#   background-color: #e3eef9;
#   color: #000000;
# }
# #T_b7d6b_row20_col3 {
#   background-color: #e3eef8;

# %%
yearly_calendar = trips.query('weekend == False').groupby(['year', 'hour', 'weekday']).trip.sum().unstack().mean(axis=1).unstack().T / 1000
yearly_calendar.fillna(0).astype(int).style.background_gradient(cmap='Blues')
# Out:
# <style type="text/css">
# #T_0e661_row0_col0, #T_0e661_row0_col1, #T_0e661_row0_col2, #T_0e661_row0_col3, #T_0e661_row1_col0, #T_0e661_row1_col3, #T_0e661_row2_col0, #T_0e661_row7_col0, #T_0e661_row17_col0, #T_0e661_row18_col0, #T_0e661_row19_col0, #T_0e661_row20_col0, #T_0e661_row20_col1 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_0e661_row1_col1, #T_0e661_row19_col1 {
#   background-color: #f1f7fd;
#   color: #000000;
# }
# #T_0e661_row1_col2, #T_0e661_row20_col2, #T_0e661_row20_col3 {
#   background-color: #eef5fc;
#   color: #000000;
# }
# #T_0e661_row2_col1, #T_0e661_row6_col1, #T_0e661_row16_col1 {
#   background-color: #b7d4ea;
#   color: #000000;
# }
# #T_0e661_row2_col2 {
#   background-color: #b3d3e8;
#   color: #000000;
# }
# #T_0e661_row2_col3, #T_0e661_row17_col3 {
#   background-color: #cadef0;
#   color: #000000;
# }
# #T_0e661_row3_col0, #T_0e661_row6_col0, #T_0e661_row6_col2, #T_0e661_row7_col1, #T_0e661_row8_col0, #T_0e661_row9_col0, #T_0e661_row10_col0, #T_0e661_row11_col0, #T_0e661_row12_col0, #T_0e661_row13_col0, #T_0e661_row16_col0 {
#   background-color: #abd0e6;
#   color: #000000;
# }
# #T_0e661_row3_col1, #T_0e661_row4_col0, #T_0e661_row4_col3, #T_0e661_row13_col2 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_0e661_row3_col2 {
#   background-color: #083b7c;
#   color: #f1f1f1;
# }
# #T_0e661_row3_col3 {
#   background-color: #1c6bb0;
#   color: #f1f1f1;
# }
# #T_0e661_row4_col1 {
#   background-color: #083877;
#   color: #f1f1f1;
# }
# #T_0e661_row4_col2 {
#   background-color: #083573;
#   color: #f1f1f1;
# }
# #T_0e661_row5_col0, #T_0e661_row12_col2, #T_0e661_row14_col0, #T_0e661_row15_col0 {
#   background-color: #3787c0;
#   color: #f1f1f1;
# }
# #T_0e661_row5_col1, #T_0e661_row9_col1, #T_0e661_row10_col2, #T_0e661_row11_col2 {
#   background-color: #79b5d9;
#   color: #000000;
# }
# #T_0e661_row5_col2, #T_0e661_row9_col2 {
#   background-color: #68acd5;
#   color: #f1f1f1;
# }
# #T_0e661_row5_col3 {
#   background-color: #5ca4d0;
#   color: #f1f1f1;
# }
# #T_0e661_row6_col3 {
#   background-color: #b0d2e7;
#   color: #000000;
# }
# #T_0e661_row7_col2 {
#   background-color: #9dcae1;
#   color: #000000;
# }
# #T_0e661_row7_col3, #T_0e661_row16_col3 {
#   background-color: #a1cbe2;
#   color: #000000;
# }
# #T_0e661_row8_col1 {
#   background-color: #87bddc;
#   color: #000000;
# }
# #T_0e661_row8_col2 {
#   background-color: #6fb0d7;
#   color: #f1f1f1;
# }
# #T_0e661_row8_col3, #T_0e661_row10_col3, #T_0e661_row11_col3 {
#   background-color: #7db8da;
#   color: #000000;
# }
# #T_0e661_row9_col3 {
#   background-color: #6aaed6;
#   color: #f1f1f1;
# }
# #T_0e661_row10_col1, #T_0e661_row11_col1 {
#   background-color: #94c4df;
#   color: #000000;
# }
# #T_0e661_row12_col1 {
#   background-color: #4a98c9;
#   color: #f1f1f1;
# }
# #T_0e661_row12_col3, #T_0e661_row15_col3 {
#   background-color: #3f8fc5;
#   color: #f1f1f1;
# }
# #T_0e661_row13_col1 {
#   background-color: #084a91;
#   color: #f1f1f1;
# }
# #T_0e661_row13_col3, #T_0e661_row14_col3 {
#   background-color: #08488e;
#   color: #f1f1f1;
# }
# #T_0e661_row14_col1 {
#   background-color: #0a539e;
#   color: #f1f1f1;
# }
# #T_0e661_row14_col2 {
#   background-color: #084285;
#   color: #f1f1f1;
# }
# #T_0e661_row15_col1 {
#   background-color: #549fcd;
#   color: #f1f1f1;
# }
# #T_0e661_row15_col2 {
#   background-color: #4292c6;
#   color: #f1f1f1;
# }
# #T_0e661_row16_col2 {
#   background-color: #a4cce3;
#   color: #000000;
# }
# #T_0e661_row17_col1 {
#   background-color: #d0e1f2;
#   color: #000000;
# }
# #T_0e661_row17_col2 {
#   background-color: #ccdff1;
#   color: #000000;
# }
# #T_0e661_row18_col1 {
#   background-color: #d6e6f4;
#   color: #000000;
# }
# #T_0e661_row18_col2 {
#   background-color: #d4e4f4;
#   color: #000000;
# }
# #T_0e661_row18_col3 {
#   background-color: #d3e4f3;
#   color: #000000;
# }
# #T_0e661_row19_col2 {
#   background-color: #e1edf8;
#   color: #000000;
# }
# #T_0e661_row19_col3 {
#   background-color: #dceaf6;
#   color: #000000;
# }
# </style>
# <table id="T_0e661">
#   <thead>
#     <tr>
#       <th class="index_name level0" >year</th>
#       <th id="T_0e661_level0_col0" class="col_heading level0 col0" >2022</th>
#       <th id="T_0e661_level0_col1" class="col_heading level0 col1" >2023</th>
#       <th id="T_0e661_level0_col2" class="col_heading level0 col2" >2024</th>
#       <th id="T_0e661_level0_col3" class="col_heading level0 col3" >2025</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >hour</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0e661_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_0e661_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_0e661_row0_col1" class="data row0 col1" >0</td>
#       <td id="T_0e661_row0_col2" class="data row0 col2" >0</td>
#       <td id="T_0e661_row0_col3" class="data row0 col3" >0</td>
#     </tr>
#     <tr>
#       <th id="T_0e661_level0_row1" class="row_heading level0 row1" >4</th>
#       <td id="T_0e661_row1_col0" class="data row1 col0" >0</td>
#       <td id="T_0e661_row1_col1" class="data row1 col1" >1</td>
#       <td id="T_0e661_row1_col2" class="data row1 col2" >2</td>
#       <td id="T_0e661_row1_col3" class="data row1 col3" >0</td>
#     </tr>
#     <tr>
#       <th id="T_0e661_level0_row2" class="row_heading level0 row2" >5</th>
#       <td id="T_0e661_row2_col0" class="data row2 col0" >0</td>
#       <td id="T_0e661_row2_col1" class="data row2 col1" >9</td>
#       <td id="T_0e661_row2_col2" class="data row2 col2" >14</td>
#       <td id="T_0e661_row2_col3" class="data row2 col3" >5</td>
#     </tr>
#     <tr>
#       <th id="T_0e661_level0_row3" class="row_heading level0 row3" >6</th>
#       <td id="T_0e661_row3_col0" class="data row3 col0" >1</td>
#       <td id="T_0e661_row3_col1" class="data row3 col1" >30</td>
#       <td id="T_0e661_row3_col2" class="data row3 col2" >43</td>
#       <td id="T_0e661_row3_col3" class="data row3 col3" >17</td>
#     </tr>
#     <tr>
#       <th id="T_0e661_level0_row4" class="row_heading level0 row4" >7</th>
#       <td id="T_0e661_row4_col0" class="data row4 col0" >3</td>
#       <td id="T_0e661_row4_col1" class="data row4 col1" >29</td>
#       <td id="T_0e661_row4_col2" class="data row4 col2" >44</td>
#       <td id="T_0e661_row4_col3" class="data row4 col3" >22</td>
#     </tr>
#     <tr>
#       <th id="T_0e661_level0_row5" class="row_heading level0 row5" >8</th>
#       <td id="T_0e661_row5_col0" class="data row5 col0" >2</td>
#       <td id="T_0e661_row5_col1" class="data row5 col1" >14</td>
#       <td id="T_0e661_row5_col2" class="data row5 col2" >23</td>
#       <td id="T_0e661_row5_col3" class="data row5 col3" >12</td>
#     </tr>
#     <tr>
#       <th id="T_0e661_level0_row6" class="row_heading level0 row6" >9</th>
#       <td id="T_0e661_row6_col0" class="data row6 col0" >1</td>
#       <td id="T_0e661_row6_col1" class="data row6 col1" >9</td>
#       <td id="T_0e661_row6_col2" class="data row6 col2" >15</td>
#       <td id="T_0e661_row6_col3" class="data row6 col3" >7</td>
#     </tr>
#     <tr>
#       <th id="T_0e661_level0_row7" class="row_heading level0 row7" >10</th>
#       <td id="T_0e661_row7_col0" class="data row7 col0" >0</td>
#       <td id="T_0e661_row7_col1" class="data row7 col1" >10</td>
#       <td id="T_0e661_row7_col2" class="data row7 col2" >17</td>
#       <td id="T_0e661_row7_col3" class="data row7 col3" >8</td>
#     </tr>
#     <tr>
#       <th id="T_0e661_level0_row8" class="row_heading level0 row8" >11</th>
#       <td id="T_0e661_row8_col0" class="data row8 col0" >1</td>
#       <td id="T_0e661_row8_col1" class="data row8 col1" >13</td>
#       <td id="T_0e661_row8_col2" class="data row8 col2" >22</td>
#       <td id="T_0e661_row8_col3" class="data row8 col3" >10</td>
#     </tr>
#     <tr>
#       <th id="T_0e661_level0_row9" class="row_heading level0 row9" >12</th>
#       <td id="T_0e661_row9_col0" class="data row9 col0" >1</td>
#       <td id="T_0e661_row9_col1" class="data row9 col1" >14</td>
#       <td id="T_0e661_row9_col2" class="data row9 col2" >23</td>
#       <td id="T_0e661_row9_col3" class="data row9 col3" >11</td>
#     </tr>
#     <tr>
#       <th id="T_0e661_level0_row10" class="row_h

# %%
fig, axes = plt.subplots(2, figsize=(16, 8))
yearly_calendar.plot(ax=axes[0], title='daily profile per year', colormap='winter')
calendar.plot(ax=axes[1], colormap='winter', alpha=.8, title='daily profile per weekday')
plt.tight_layout()

# %%
# Average trips per month
trips.groupby(['year', 'month']).trip.sum().unstack().mean(axis=1).plot.bar()
# Out:
# <Axes: xlabel='year'>

# %%
trips.groupby('date').trip.sum().sort_index().fillna(0).rolling(window=15).mean().plot(figsize=(22,4))
# Out:
# <Axes: xlabel='date'>

# %%
fig, axes = plt.subplots(2, 1, figsize=(16,8))

timeline = pd.MultiIndex.from_product([trips.year.unique(), trips.month.unique()])
trips[['year', 'month']].value_counts().reindex(timeline).sort_index().plot.bar(ax=axes[0], title='Monthly trip count')

timeline = pd.MultiIndex.from_product([trips.year.unique(), trips.weekday.unique()])
trips[['year', 'weekday']].value_counts().reindex(timeline).sort_index().plot.bar(ax=axes[1], title='Trip count throughout the week')

plt.tight_layout()

# %% [markdown]
# ### Spatiality

# %%
distances = distance_matrix(stations_GPS, stations_GPS).flatten()
print('mean inter-station distance in meters:', distances[distances>0].mean())
# Out:
# mean inter-station distance in meters: 3612.8215289514865

# %%
trips_per_station = oslo_lib.get_trips_per_station(trips, stations)
(trips_per_station.trip//1e4).astype(int).value_counts().sort_index().plot.bar(title='distribution of 10k trips per station', 
                                                                               rot=45)
# Out:
# <Axes: title={'center': 'distribution of 10k trips per station'}, xlabel='trip'>

# %%
ax = trips_per_station.plot(figsize=(16,8), 
                            edgecolor='k',
                            alpha=.6,
                            cmap='Reds',
                            column=trips_per_station.trip,
                            markersize=trips_per_station.trip/1000,
                            legend=True,
                           )
ctx.add_basemap(ax=ax, crs=trips_per_station.crs, zoom=13, source=ctx.providers.CartoDB.Positron)
plt.title('Number of trips starting/ending at each station')
# Out:
# Text(0.5, 1.0, 'Number of trips starting/ending at each station')

# %%
ax = trips_per_station.plot(figsize=(24,12), 
                            edgecolor='k',
                            alpha=.6,
                            cmap='tab10',
                            column='station_class',
                            markersize=trips_per_station.trip/1000,
                            legend=True
                           )
ctx.add_basemap(ax=ax, crs=trips_per_station.crs, zoom=13, source=ctx.providers.CartoDB.Positron)
plt.title('Station class in terms of numbr of trips')
# Out:
# Text(0.5, 1.0, 'Station class in terms of numbr of trips')

# %%
trips_per_station.to_pickle(f'{city}/trips_per_station.pkl')
