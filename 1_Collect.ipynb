# %%
import oslo_lib
import pandas as pd

city = 'Milan'
providers = {'Oslo': 'oslobysykkel.no', 'Edinburgh': 'edinburghcyclehire.com', 'Milan':'bikemi.com'}
provider = providers[city]

df = oslo_lib.collect_data(years = [2018, 2019, 2020, 2021, 2022, 2023, 2024, 2025], months = range(1, 13), provider=provider)
df.to_pickle(f'{city}/{city.lower()}_data.pkl')

start_stations = df.set_index('start_station_id')[['start_station_longitude', 'start_station_latitude', 'start_station_name', 'start_station_description']]
start_stations.columns = ['longitude', 'latitude', 'name', 'description']

end_stations = df.set_index('end_station_id')[['end_station_longitude', 'end_station_latitude', 'end_station_name', 'end_station_description']]
end_stations.columns = ['longitude', 'latitude', 'name', 'description']

stations = pd.concat([start_stations,end_stations])
stations = stations[~stations.index.duplicated()].sort_index()

stations.to_pickle(f'{city}/stations.pkl')

trips = df[['started_at', 'ended_at', 'start_station_id', 'end_station_id', 'duration']].copy()
trips.to_pickle(f'{city}/trips.pkl')

# %%
available_data = pd.read_xml('https://data.urbansharing.com/')
available_data['provider'] = available_data['Key'].dropna().apply(lambda x : x.split('.')[0])
available_data.provider.value_counts()
# Out:
# provider
# bergenbysykkel        176
# oslobysykkel          156
# trondheimbysykkel     152
# edinburghcyclehire     96
# oslovintersykkel       64
# bikemi                 62
# Name: count, dtype: int64

# %%
available_data.set_index('provider').loc['bikemi']
# Out:
#           Name IsTruncated                               Key    Generation  \
# provider
# bikemi    None         NaN   bikemi.com/trips/v1/2022/12.csv  1.675189e+15
# bikemi    None         NaN  bikemi.com/trips/v1/2022/12.json  1.675189e+15
# bikemi    None         NaN   bikemi.com/trips/v1/2023/01.csv  1.677608e+15
# bikemi    None         NaN  bikemi.com/trips/v1/2023/01.json  1.677608e+15
# bikemi    None         NaN   bikemi.com/trips/v1/2023/02.csv  1.680287e+15
# ...        ...         ...                               ...           ...
# bikemi    None         NaN  bikemi.com/trips/v1/2025/04.json  1.748715e+15
# bikemi    None         NaN   bikemi.com/trips/v1/2025/05.csv  1.749147e+15
# bikemi    None         NaN  bikemi.com/trips/v1/2025/05.json  1.749147e+15
# bikemi    None         NaN   bikemi.com/trips/v1/2025/06.csv  1.749147e+15
# bikemi    None         NaN  bikemi.com/trips/v1/2025/06.json  1.749147e+15
#
#           MetaGeneration              LastModified  \
# provider
# bikemi               1.0  2023-01-31T18:15:55.224Z
# bikemi               1.0  2023-01-31T18:15:57.247Z
# bikemi               1.0  2023-02-28T18:16:05.271Z
# bikemi               1.0  2023-02-28T18:16:07.881Z
# bikemi               1.0  2023-03-31T18:16:48.766Z
# ...                  ...                       ...
# bikemi               1.0  2025-05-31T18:17:15.519Z
# bikemi               1.0  2025-06-05T18:17:00.514Z
# bikemi               1.0  2025-06-05T18:17:07.126Z
# bikemi               1.0  2025-06-05T18:17:15.930Z
# bikemi               1.0  2025-06-05T18:17:16.824Z
#
#                                         ETag         Size
# provider
# bikemi    "efbb84a41481d58c9678b7c0cae29357"   35559242.0
# bikemi    "d49caea5ac5c652038d8ef73372a30ab"   79740134.0
# bikemi    "7bb7ad97ec78a427a1ebc435d9e30e7f"   41805382.0
# bikemi    "f6d90ead6df72b60a3cb523d39b276af"   93744716.0
# bikemi    "ab57a2e1fe11080dffc2d691becd4f4b"   49805805.0
# ...                                      ...          ...
# bikemi    "db7875eecf0d1792a49ee9ccd948f095"  148459586.0
# bikemi    "ec06ae51c09d940399f5a302c615c6d9"   79528640.0
# bikemi    "f686fb13c6c8ad45ef0e3ed653bfea6f"  178147582.0
# bikemi    "1604aa12c306112134627472ed288c8a"   12095192.0
# bikemi    "cca62d1a0e24e32dfc14b5f144efc047"   27093710.0
#
# [62 rows x 8 columns]
